# %% [markdown]
# # Data Visualization Libraries

# %% [markdown]
# ## Matplotlib
#
# Matplotlib is a python library that is specially designed for the development of grphical elements such as plots and charts for interactive data visualization
#
# Matplotlib is inspired from the Matlab software and reprodouce many of it's feature
#
# Matplotlib support all the popular charts (histograms, line chart, bar charts, scatterplot etc)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
car=pd.read_csv('Car_sales.csv')
car.head()
# Out:
#     Manufacturer              Model  Sales in thousands  4-year resale value  \
# 0     Mitsubishi  3000GT                          0.110            20.940000
# 1          Dodge  Viper                           0.916            58.470000
# 2  Mercedes-Benz  CL500                           0.954            18.072975
# 3     Oldsmobile  Cutlass                         1.112            11.240000
# 4        Porsche  Carrera Coupe                   1.280            60.625000
#
#   Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  Width  \
# 0    Passenger              25.450          3.0       161.0       97.2   72.4
# 1    Passenger              69.725          8.0       450.0       96.2   75.7
# 2    Passenger              85.500          5.0       302.0      113.6   73.1
# 3    Passenger              18.145          3.1       150.0      107.0   69.4
# 4    Passenger              71.020          3.4       300.0       92.6   69.5
#
# ...

# %% [markdown]
# # 1. Line Plot

# %%
#Sorting dataset by 'Sales in thousands'
car=car.sort_values('Sales in thousands')

# %%
#Plotting simple line plot to see thre trend of 'Sales in thousands'
plt.plot(car['Sales in thousands'])
plt.show()

# %% [markdown]
# # 2. Bar Plot

# %%
#Mean 4-year resale value for each Manufacturer
plt.figure(figsize=(10,8)) # Creates a new figure and allows you to set different parameters like figuresize()
for group,data in car.groupby('Manufacturer'):
    plt.barh(group,data['4-year resale value'].mean())

# %%
#plotting Vehicle type Manufacturer make
vt_dict=dict()
for i in set(car['Vehicle type']):
    vt_dict[i]=car[car['Vehicle type']==i].Manufacturer.count()
plt.bar(vt_dict.keys(),vt_dict.values())
plt.show()

# %% [markdown]
# # 3. Pie Chart

# %%
m_dict=dict()
plt.figure(figsize=(10,8))

for manufacturer in set(car.Manufacturer):
    m_dict[manufacturer]=car[car.Manufacturer==manufacturer].Manufacturer.count()
plt.pie(m_dict.values(),labels=m_dict.keys())
plt.show()

# %% [markdown]
# # 4. Scatter Plot

# %%
plt.scatter(car['Fuel capacity'],car['Fuel efficiency'])

# %% [markdown]
# ## Seaborn
#
# Seaborn is built on top of matplotlib and provide a very simple yet intutive interface for building visualization
#
# Unique feature of Seaborn is that is designed in such a way that you write way lesser code to achieve high grade visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %% [markdown]
# ## 1. Join Plot

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %% [markdown]
# ### 2. Box Plot

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %% [markdown]
# ### 3. Swarmplot

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')
# Out:
# C:\Users\jasor\anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\jasor\anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %% [markdown]
# ### 4. HeatMap

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %% [markdown]
# ## Cufflinks
#
# Cufflinks is another library that connects the Pandas data frame with Plotly enabling users to create visualizations directly from Pandas.
# The library binds the power of Plotly with the flexibility of Pandas for easy plotting

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 4.9.0

# %%
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.484996 -1.029315 -1.568375 -0.864464
# 1 -1.758657 -0.353904 -0.995450 -0.295687
# 2  0.416598  0.112774  0.911642  0.571851
# 3  0.807377  0.882197  1.209189 -1.219791
# 4 -1.596147  1.463199 -0.002164  0.375137

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>
#
#
#             <div id="32f9ef1a-a81e-4862-965e-18e5e27e5e62" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("32f9ef1a-a81e-4862-965e-18e5e27e5e62")) {
#                     Plotly.newPlot(
#                         '32f9ef1a-a81e-4862-965e-18e5e27e5e62',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="aa486cad-fb92-43a5-8b82-e2483c2431ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aa486cad-fb92-43a5-8b82-e2483c2431ad")) {
#                     Plotly.newPlot(
#                         'aa486cad-fb92-43a5-8b82-e2483c2431ad',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="4aab9cce-c807-40d5-99dd-fee0a468bd7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4aab9cce-c807-40d5-99dd-fee0a468bd7d")) {
#                     Plotly.newPlot(
#                         '4aab9cce-c807-40d5-99dd-fee0a468bd7d',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# C:\Users\jasor\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\jasor\anaconda3\lib\site-packages\cufflinks\plotlytools.py:851: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="c43eef51-fd67-4839-9969-0563ced0d2f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c43eef51-fd67-4839-9969-0563ced0d2f9")) {
#                     Plotly.newPlot(
#                         'c43eef51-fd67-4839-9969-0563ced0d2f9',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="05478e48-1ee4-40dc-b3f9-da74accdfa97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("05478e48-1ee4-40dc-b3f9-da74accdfa97")) {
#                     Plotly.newPlot(
#                         '05478e48-1ee4-40dc-b3f9-da74accdfa97',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="0f4ffa6c-9568-450c-9030-f4efda3c3fda" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0f4ffa6c-9568-450c-9030-f4efda3c3fda")) {
#                     Plotly.newPlot(
#                         '0f4ffa6c-9568-450c-9030-f4efda3c3fda',
# ...

# %% [markdown]
# ## Plotly
#
# Python graphing library make interactive, publication-quality graphs

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter_3d(df, x='sepal_length', y='sepal_width', z='petal_width',
              color='species')
fig.show()
# Out:
# <div>
#
#
#             <div id="12492c3f-bf5b-4869-9b29-8ce82261792c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12492c3f-bf5b-4869-9b29-8ce82261792c")) {
#                     Plotly.newPlot(
#                         '12492c3f-bf5b-4869-9b29-8ce82261792c',
# ...

# %%
import plotly.express as px
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year", animation_group="country",
           size="pop", color="continent", hover_name="country",
           log_x=True, size_max=55, range_x=[100,100000], range_y=[10,90])
# Out:
# <div>
#
#
#             <div id="f9a68bce-014f-4b78-ba8c-120583c5263d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f9a68bce-014f-4b78-ba8c-120583c5263d")) {
#                     Plotly.newPlot(
#                         'f9a68bce-014f-4b78-ba8c-120583c5263d',
# ...

# %% [markdown]
# ## Bokeh
#
# Bokeh is an interactive visualization library for modern web browsers.
# It provides elegant, concise construction of versatile graphics, and affords high-performance interactivity over large or streaming datasets.
# Bokeh can help anyone who would like to quickly and easily make interactive plots, dashboards, and data applications.

# %%
from bokeh.layouts import row
from bokeh.plotting import figure, output_file, show

factors = ["a", "b", "c", "d", "e", "f", "g", "h"]
x =  [50, 40, 65, 10, 25, 37, 80, 60]

dot = figure(title="Categorical Dot Plot", tools="", toolbar_location=None,
            y_range=factors, x_range=[0,100])

dot.segment(0, factors, x, factors, line_width=2, line_color="green", )
dot.circle(x, factors, size=15, fill_color="orange", line_color="green", line_width=3, )

factors = ["foo 123", "bar:0.2", "baz-10"]
x = ["foo 123", "foo 123", "foo 123", "bar:0.2", "bar:0.2", "bar:0.2", "baz-10",  "baz-10",  "baz-10"]
y = ["foo 123", "bar:0.2", "baz-10",  "foo 123", "bar:0.2", "baz-10",  "foo 123", "bar:0.2", "baz-10"]
colors = [
    "#0B486B", "#79BD9A", "#CFF09E",
    "#79BD9A", "#0B486B", "#79BD9A",
    "#CFF09E", "#79BD9A", "#0B486B"
]

hm = figure(title="Categorical Heatmap", tools="hover", toolbar_location=None,
            x_range=factors, y_range=factors)

hm.rect(x, y, color=colors, width=1, height=1)

output_file("categorical.html", title="categorical.py example")

show(row(hm, dot, sizing_mode="scale_width"))  # open a browser

# %% [markdown]
# ###  More Libraries
#
# Ggplot, Pygal, Altair, Geoplotlib, Gleam, Missingno, Leather
#
# https://www.fusioncharts.com/blog/best-python-data-visualization-libraries/
